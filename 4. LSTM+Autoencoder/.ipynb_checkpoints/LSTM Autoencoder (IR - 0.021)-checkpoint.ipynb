# %%
#importing packages
import pandas as pd
import numpy as np

# %%
# Importing the dataset
X = pd.read_csv('../Datasets/NB.csv')
X['Fault'] = 0

y = pd.read_csv('../Datasets/IR - 21.csv')
y['Fault'] = 1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(X, test_size = 0.2, random_state = 0)

y_train, y_test = train_test_split(y, test_size = 0.2, random_state = 0)

# %%
train = X_train.append(y_train)
train
# Out:
#               DE        FE  Fault
# 103476  0.062585  0.041091      0
# 96984  -0.075102 -0.013765      0
# 114732 -0.048190 -0.001233      0
# 10916   0.069260  0.028558      0
# 37646   0.040054  0.065335      0
# ...          ...       ...    ...
# 45891   0.479590 -0.055473      1
# 117952  1.090346 -0.036776      1
# 42613  -0.061319  0.245724      1
# 43567  -0.548219  0.040475      1
# 68268  -0.225785 -0.049104      1
#
# [193848 rows x 3 columns]

# %%
test = X_test.append(y_test)
test
# Out:
#               DE        FE  Fault
# 121079  0.046313  0.054651      0
# 107924 -0.015855  0.061636      0
# 22678  -0.065297  0.122862      0
# 55190  -0.112652  0.066978      0
# 92048   0.023991  0.034105      0
# ...          ...       ...    ...
# 103358 -0.201013 -0.113411      1
# 54412  -0.208323  0.096975      1
# 50632  -0.115735 -0.066156      1
# 89251  -0.534005 -0.094920      1
# 65637   0.043045  0.032256      1
#
# [48462 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train = pd.DataFrame(scaler.fit_transform(train))
train.sample(frac=1)

test = pd.DataFrame(scaler.transform(test))

# %%
train = train.values.reshape(-1, 1, 3)

test  = test.values.reshape(-1, 1, 3)

# %%
from keras.layers import Input, Dropout, Dense, LSTM, RepeatVector, TimeDistributed
from keras.models import Model, Sequential, load_model
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
# Input layer:
model=Sequential([
    LSTM(32, activation='relu', input_shape=(train.shape[1],train.shape[2])),
    Dropout(0.2),
    RepeatVector(train.shape[1]),
    LSTM(32, activation='relu', return_sequences=True),
    Dropout(0.2),
    TimeDistributed(Dense(train.shape[2]))
])

model.compile(loss='mse',optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 32)                4608
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 1, 32)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 32)             8320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 32)             0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 1, 3)              99
# =================================================================
# Total params: 13,027
# Trainable params: 13,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train model for 100 epochs, batch size of 1000: 
NUM_EPOCHS=100
BATCH_SIZE=1000

history=model.fit(train,train, 
                  batch_size=BATCH_SIZE, 
                  epochs=NUM_EPOCHS,
                  validation_split=0.1,
                  shuffle=True)
# Out:
# Train on 174463 samples, validate on 19385 samples
# Epoch 1/100
# 174463/174463 [==============================] - 3s 15us/step - loss: 0.1205 - accuracy: 0.8041 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 2/100
# 174463/174463 [==============================] - 2s 10us/step - loss: 0.0155 - accuracy: 0.8840 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 3/100
# 174463/174463 [==============================] - 2s 10us/step - loss: 0.0118 - accuracy: 0.8782 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 4/100
# 174463/174463 [==============================] - 2s 10us/step - loss: 0.0101 - accuracy: 0.8923 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 5/100
# 174463/174463 [==============================] - 2s 9us/step - loss: 0.0088 - accuracy: 0.9010 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 6/100
# 174463/174463 [==============================] - 2s 10us/step - loss: 0.0078 - accuracy: 0.9049 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 7/100
# 174463/174463 [==============================] - 2s 10us/step - loss: 0.0070 - accuracy: 0.9075 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 8/100
# 174463/174463 [==============================] - 2s 10us/step - loss: 0.0065 - accuracy: 0.9091 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 9/100
# 174463/174463 [==============================] - 2s 11us/step - loss: 0.0061 - accuracy: 0.9096 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 10/100
# 174463/174463 [==============================] - 2s 11us/step - loss: 0.0054 - accuracy: 0.9099 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 11/100
# 174463/174463 [==============================] - 2s 12us/step - loss: 0.0050 - accuracy: 0.9100 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 12/100
# 174463/174463 [==============================] - 2s 11us/step - loss: 0.0047 - accuracy: 0.9100 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 13/100
# 174463/174463 [==============================] - 2s 11us/step - loss: 0.0044 - accuracy: 0.9099 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 14/100
# 174463/174463 [==============================] - 2s 11us/step - loss: 0.0042 - accuracy: 0.9097 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 15/100
# 174463/174463 [==============================] - 2s 10us/step - loss: 0.0040 - accuracy: 0.9095 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 16/100
# 174463/174463 [==============================] - 2s 10us/step - loss: 0.0037 - accuracy: 0.9097 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 17/100
# 174463/174463 [==============================] - 2s 10us/step - loss: 0.0036 - accuracy: 0.9097 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 18/100
# 174463/174463 [==============================] - 2s 10us/step - loss: 0.0034 - accuracy: 0.9101 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 19/100
# 174463/174463 [==============================] - 2s 11us/step - loss: 0.0033 - accuracy: 0.9103 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch
-04 - val_accuracy: 1.0000
# Epoch 81/100
# 174463/174463 [==============================] - 4s 21us/step - loss: 0.0024 - accuracy: 0.9516 - val_loss: 3.2600e-04 - val_accuracy: 1.0000
# Epoch 82/100
# 174463/174463 [==============================] - 4s 22us/step - loss: 0.0024 - accuracy: 0.9510 - val_loss: 3.6554e-04 - val_accuracy: 1.0000
# Epoch 83/100
# 174463/174463 [==============================] - 4s 22us/step - loss: 0.0024 - accuracy: 0.9514 - val_loss: 3.4162e-04 - val_accuracy: 1.0000
# Epoch 84/100
# 174463/174463 [==============================] - 4s 20us/step - loss: 0.0023 - accuracy: 0.9508 - val_loss: 4.5480e-04 - val_accuracy: 1.0000
# Epoch 85/100
# 174463/174463 [==============================] - 3s 20us/step - loss: 0.0023 - accuracy: 0.9505 - val_loss: 3.2741e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 174463/174463 [==============================] - 4s 21us/step - loss: 0.0024 - accuracy: 0.9519 - val_loss: 3.9490e-04 - val_accuracy: 1.0000
# Epoch 87/100
# 174463/174463 [==============================] - 3s 20us/step - loss: 0.0024 - accuracy: 0.9511 - val_loss: 3.0926e-04 - val_accuracy: 1.0000
# Epoch 88/100
# 174463/174463 [==============================] - 3s 20us/step - loss: 0.0023 - accuracy: 0.9516 - val_loss: 3.6723e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 174463/174463 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.95 - 4s 21us/step - loss: 0.0023 - accuracy: 0.9503 - val_loss: 3.5466e-04 - val_accuracy: 1.0000
# Epoch 90/100
# 174463/174463 [==============================] - 4s 20us/step - loss: 0.0023 - accuracy: 0.9504 - val_loss: 3.6040e-04 - val_accuracy: 1.0000
# Epoch 91/100
# 174463/174463 [==============================] - 4s 21us/step - loss: 0.0023 - accuracy: 0.9512 - val_loss: 3.1487e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 174463/174463 [==============================] - 4s 21us/step - loss: 0.0024 - accuracy: 0.9517 - val_loss: 3.1854e-04 - val_accuracy: 1.0000
# Epoch 93/100
# 174463/174463 [==============================] - 4s 21us/step - loss: 0.0024 - accuracy: 0.9526 - val_loss: 3.4011e-04 - val_accuracy: 1.0000
# Epoch 94/100
# 174463/174463 [==============================] - 4s 21us/step - loss: 0.0024 - accuracy: 0.9517 - val_loss: 3.1403e-04 - val_accuracy: 1.0000
# Epoch 95/100
# 174463/174463 [==============================] - 4s 20us/step - loss: 0.0023 - accuracy: 0.9524 - val_loss: 3.1172e-04 - val_accuracy: 1.0000
# Epoch 96/100
# 174463/174463 [==============================] - 4s 21us/step - loss: 0.0023 - accuracy: 0.9517 - val_loss: 3.1745e-04 - val_accuracy: 1.0000
# Epoch 97/100
# 174463/174463 [==============================] - 4s 21us/step - loss: 0.0023 - accuracy: 0.9524 - val_loss: 3.8930e-04 - val_accuracy: 1.0000
# Epoch 98/100
# 174463/174463 [==============================] - 4s 21us/step - loss: 0.0023 - accuracy: 0.9526 - val_loss: 2.9501e-04 - val_accuracy: 1.0000
# Epoch 99/100
# 174463/174463 [==============================] - 3s 20us/step - loss: 0.0023 - accuracy: 0.9513 - val_loss: 3.3771e-04 - val_accuracy: 1.0000
# Epoch 100/100
# 174463/174463 [==============================] - 3s 20us/step - loss: 0.0023 - accuracy: 0.9516 - val_loss: 3.2000e-04 - val_accuracy: 1.0000

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend(loc='upper right')
plt.xlabel('Epochs')
plt.ylabel('Loss, [mse]')
plt.show()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
pred_train = model.predict(train)

# %%
pred_train = pred_train.reshape(pred_train.shape[0],pred_train.shape[2])
train = train.reshape(train.shape[0],train.shape[2])

# %%
import seaborn as sns

scored = np.mean(np.abs(pred_train-train), axis = 1)
plt.figure()
g = sns.distplot(scored, bins = 50, kde= True, color = 'blue');
plt.title('Loss Distribution')
plt.xlabel('Loss (MSE)')
plt.show()

# %%
TH = 0.04
pred_train = pd.DataFrame(pred_train)
scored_train = pd.DataFrame()
scored_train['Loss_mae'] = np.mean(np.abs(pred_train-train), axis = 1)
scored_train['Threshold'] = TH
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']

# %%
scored_train['Loss_mae'].mean()
# Out:
# 0.009063424950917798

# %%
scored_train.plot(logy=True,  figsize = (16,4), xlim =[0,len(scored_train)])
plt.xlabel('Data points')
plt.ylabel('Loss (MAE)')
# Out:
# Text(0, 0.5, 'Loss (MAE)')

# %%
scored_train
# Out:
#         Loss_mae  Threshold  Anomaly
# 0       0.006289       0.04    False
# 1       0.008594       0.04    False
# 2       0.006019       0.04    False
# 3       0.005445       0.04    False
# 4       0.005704       0.04    False
# ...          ...        ...      ...
# 193843  0.008599       0.04    False
# 193844  0.018970       0.04    False
# 193845  0.009376       0.04    False
# 193846  0.008460       0.04    False
# 193847  0.006452       0.04    False
#
# [193848 rows x 3 columns]

# %%
anomalies = scored_train[scored_train['Anomaly'] == True]
print(anomalies)
print(anomalies.shape)
# Out:
#         Loss_mae  Threshold  Anomaly
# 96976   0.053895       0.04     True
# 96990   0.057270       0.04     True
# 96992   0.041367       0.04     True
# 97000   0.064494       0.04     True
# 97037   0.054270       0.04     True
# ...          ...        ...      ...
# 193645  0.042438       0.04     True
# 193682  0.116241       0.04     True
# 193687  0.043470       0.04     True
# 193763  0.048855       0.04     True
# 193765  0.046620       0.04     True
#
# [1787 rows x 3 columns]
# (1787, 3)

# %%
f, (ax1) = plt.subplots(figsize=(16, 4))
ax1.plot(scored_train.index, scored_train.Loss_mae, label='Loss(MAE)');
ax1.plot(scored_train.index, scored_train.Threshold, label='Threshold')
g = sns.scatterplot(x=anomalies.index , y=anomalies.Loss_mae, label='anomaly', color='red')
g.set(xlim = (0, len(scored_train.index)))
plt.title('Anomalies')
plt.xlabel('Data points')
plt.ylabel('Loss (MAE)')
plt.legend();

# %%
pred_test = model.predict(test)

# %%
score = model.evaluate(test,test)
score
# Out:
# 48462/48462 [==============================] - 3s 70us/step
# [0.00019731272016422567, 0.9580289721488953]

# %%
pred_test = pred_test.reshape(pred_test.shape[0],pred_test.shape[2])
test = test.reshape(test.shape[0],test.shape[2])

# %%
import seaborn as sns

scored_test = np.mean(np.abs(pred_test-test), axis = 1)
plt.figure()
g = sns.distplot(scored_test, bins = 10, kde= True);
plt.title('Loss Distribution')
plt.xlabel('Loss (MSE)')
plt.show()

# %%
scored_test = pd.DataFrame()
scored_test['Loss_mae'] = np.mean(np.abs(pred_test-test), axis = 1)
scored_test['Threshold'] = TH
scored_test['Anomaly'] = scored_test['Loss_mae'] > scored_test['Threshold']

scored_test
# Out:
#        Loss_mae  Threshold  Anomaly
# 0      0.006579       0.04    False
# 1      0.005399       0.04    False
# 2      0.010012       0.04    False
# 3      0.010551       0.04    False
# 4      0.003963       0.04    False
# ...         ...        ...      ...
# 48457  0.010907       0.04    False
# 48458  0.004960       0.04    False
# 48459  0.006811       0.04    False
# 48460  0.013821       0.04    False
# 48461  0.000843       0.04    False
#
# [48462 rows x 3 columns]

# %%
scored_test['Loss_mae'].mean()
# Out:
# 0.009041728335465021

# %%
scored_test.plot(logy=True,  figsize = (16,4), xlim =[0,len(scored_test)])
plt.xlabel('Data points')
plt.ylabel('Loss (MAE)')
# Out:
# Text(0, 0.5, 'Loss (MAE)')

# %%
IR_anomalies = scored_test[scored_test['Anomaly'] == True]
print(IR_anomalies)
print(IR_anomalies.shape)
# Out:
#        Loss_mae  Threshold  Anomaly
# 24273  0.063103       0.04     True
# 24324  0.052119       0.04     True
# 24500  0.046365       0.04     True
# 24505  0.041748       0.04     True
# 24560  0.058906       0.04     True
# ...         ...        ...      ...
# 48007  0.048629       0.04     True
# 48238  0.054642       0.04     True
# 48243  0.043342       0.04     True
# 48422  0.065028       0.04     True
# 48425  0.042203       0.04     True
#
# [406 rows x 3 columns]
# (406, 3)

# %%
f, (ax2) = plt.subplots(figsize=(18, 6))
ax2.plot(scored_test.index, scored_test.Loss_mae, label='Loss(MAE)');
ax2.plot(scored_test.index, scored_test.Threshold, label='Threshold')
g = sns.scatterplot(x=IR_anomalies.index , y=IR_anomalies.Loss_mae, label='anomaly', color='red')
g.set(xlim = (0, len(scored_test.index)))
plt.title('Anomalies')
plt.xlabel('Data points')
plt.ylabel('Loss (MAE)')
plt.legend();

# %%
print(score[1])
# Out:
# 0.9580289721488953

# %%
print("Accuracy: {:.2f}%".format(score[1]*100))
# Out:
# Accuracy: 95.80%

# %%
print("Anomalies: {}".format(IR_anomalies['Anomaly'].count()))
# Out:
# Anomalies: 406
