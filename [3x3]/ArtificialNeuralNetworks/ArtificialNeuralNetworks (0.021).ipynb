# %%
#importing packages
import pandas as pd
import numpy as np

# %%
def time_signal(file, code):

    import re
    try:
        data = pd.read_csv(f"../../{file}.csv")
        for key in data:
            if re.findall(rf"({code})", key):
                dict_code = key
        unit_conv = 0.0254
        x = data[dict_code] * unit_conv
        return x
    except:
        print('File does not exist or code wrong. Code must be either "DE or "FE" ')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

normal_sig = time_signal(file='NB', code='DE')
ir_sig = time_signal(file='IR - 21', code='DE') 
or_sig = time_signal(file='OR - 21', code='DE') 

# plotting

fig, (plt1, plt2, plt3) = plt.subplots(1, 3, sharey = True, figsize=(12, 3), constrained_layout=True)
plt1.set_xlabel("time $(s)$")
plt1.set_ylabel("acceleration $(m/s^2)$")
plt1.set_title('Normal state')
plt1.axis((0,591,-0.1,0.1))
plt1.plot(normal_sig)
plt2.set_xlabel("time $(s)$")
plt2.set_ylabel("acceleration $(m/s^2)$")
plt2.set_title('Inner Race fault (diameter 0.021")')
plt2.axis((0,591,-0.1,0.1))
plt2.plot(ir_sig)
plt3.set_xlabel("time $(s)$")
plt3.set_ylabel("acceleration $(m/s^2)$")
plt3.set_title('Outer Race fault (diameter 0.021")')
plt3.axis((0,591,-0.1,0.1))
plt3.plot(or_sig)
fig.suptitle('Acceleration data recorded at the drive end')
fig.show()
# Out:
# C:\Users\leste\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
# Importing the dataset
dataset = pd.read_csv('../CWRU Dataset-2.csv')
X = dataset.iloc[:, 1:4].values
y = dataset.iloc[:, 0:1].values

# %%
dataset.head(5)
# Out:
#   Bearing  Fault Diameter        DE        FE
# 0  Normal             0.0  0.064254  0.038625
# 1  Normal             0.0  0.063002  0.096769
# 2  Normal             0.0 -0.004381  0.127382
# 3  Normal             0.0 -0.035882  0.144640
# 4  Normal             0.0 -0.023991  0.086702

# %%
#Retrieve Random Data
dataset.sample(10)
# Out:
#                     Bearing  Fault Diameter        DE        FE
# 138124  Inner Race (0.021")           0.021  0.139694  0.077662
# 4615                 Normal           0.000  0.024199 -0.020135
# 68258                Normal           0.000 -0.049859  0.087318
# 242092  Inner Race (0.021")           0.021 -0.049137  0.203811
# 103683               Normal           0.000 -0.062585 -0.065335
# 55212                Normal           0.000 -0.058830  0.076224
# 64227                Normal           0.000 -0.035673  0.041913
# 87910                Normal           0.000  0.120997 -0.046844
# 142477  Inner Race (0.021")           0.021 -0.027208 -0.232369
# 82457                Normal           0.000 -0.051528  0.085880

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
labelencoder_y = LabelEncoder()
y[:,0] = labelencoder_y.fit_transform(y[:,0])
ct = ColumnTransformer([("Bearing", OneHotEncoder(), [0])],    remainder = 'passthrough')
y = ct.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
classifier = Sequential()

# %%
classifier.add(Dense(output_dim = 3, kernel_initializer = 'uniform', activation = 'relu', input_dim = 3))
# Out:
# C:\Users\leste\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(kernel_initializer="uniform", activation="relu", input_dim=3, units=3)`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Dense(output_dim = 3, kernel_initializer = 'uniform', activation = 'relu'))
# Out:
# C:\Users\leste\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(kernel_initializer="uniform", activation="relu", units=3)`
#   """Entry point for launching an IPython kernel.

# %%
classifier.add(Dense(output_dim = 3, kernel_initializer = 'uniform', activation = 'sigmoid'))
# Out:
# C:\Users\leste\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(kernel_initializer="uniform", activation="sigmoid", units=3)`
#   """Entry point for launching an IPython kernel.

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model = classifier.fit(X_train, y_train, batch_size = 100, nb_epoch = 100)
# Out:
# C:\Users\leste\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# Epoch 1/100
# 290688/290688 [==============================] - 4s 14us/step - loss: 0.4352 - accuracy: 0.7583
# Epoch 2/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3321 - accuracy: 0.7778
# Epoch 3/100
# 290688/290688 [==============================] - 4s 14us/step - loss: 0.3171 - accuracy: 0.7776
# Epoch 4/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3129 - accuracy: 0.7782
# Epoch 5/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3112 - accuracy: 0.7780
# Epoch 6/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3105 - accuracy: 0.7786
# Epoch 7/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3100 - accuracy: 0.7775
# Epoch 8/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3090 - accuracy: 0.7787
# Epoch 9/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3080 - accuracy: 0.7803
# Epoch 10/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3075 - accuracy: 0.7789
# Epoch 11/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3073 - accuracy: 0.7793
# Epoch 12/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3072 - accuracy: 0.7789
# Epoch 13/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3071 - accuracy: 0.7793
# Epoch 14/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3071 - accuracy: 0.7794
# Epoch 15/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3070 - accuracy: 0.7789
# Epoch 16/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3069 - accuracy: 0.7804
# Epoch 17/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3069 - accuracy: 0.7795
# Epoch 18/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3069 - accuracy: 0.7803
# Epoch 19/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3069 - accuracy: 0.7796
# Epoch 20/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3068 - accuracy: 0.7785
# Epoch 21/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3068 - accuracy: 0.7790
# Epoch 22/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3068 - accuracy: 0.7797
# Epoch 23/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3068 - accuracy: 0.7792
# Epoch 24/100
# 290688/290688 [==============================] - 3s 12us/step - loss: 0.3067 - accuracy: 0.7795
# Epoch 25/100
# 290688/290688 [==============================] - 3s 11us/step - loss: 0.3067 - accuracy: 0.7796
# Epoch 26/100
# 290688/290688 [==============================] - 3s 12us/step - loss: 0.3067 - accuracy: 0.7796
# Epoch 27/100
# 290688/290688 [==============================] - 3s 10us/step - loss: 0.3067 - accuracy: 0.7800
# Epoch 28/100
# 290688/290688 [==============================] - 3s 10us/step - loss: 0.3067 - accuracy: 0.7787
# Epoch 29/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3066 - accuracy: 0.7800
# Epoch 30/100
# 290688/290688 [==============================] - 3s 10us/step - loss: 0.3066 - accuracy: 0.7802
# Epoch 31/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3066 - accuracy: 0.7793
# Epoch 32/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3066 - accuracy: 0.7798
# Epoch 33/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3066 - accuracy: 0.7792
# Epoch 34/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3066 - accuracy: 0.7798
# Epoch 35/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3066 - accuracy: 0.7798
# Epoch 36/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3066 - accuracy: 0.7793
# Epoch 37/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3066 - accuracy: 0.7799
# Epoch 38/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3066 - accuracy: 0.7789
# Epoch 39/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7795
# Epoch 40/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3066 - accuracy: 0.7799
# Epoch 41/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7789
# Epoch 42/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7809
# Epoch 43/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7797
# Epoch 44/100
# 290688/290688 [==============================] - 3s 11us/step - loss: 0.3065 - accuracy: 0.7810
# Epoch 45/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7785
# Epoch 46/100
# 290688/290688 [==============================] - 3s 10us/step - loss: 0.3065 - accuracy: 0.7800
# Epoch 47/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7797
# Epoch 48/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7787
# Epoch 49/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7789
# Epoch 50/100
# 290688/290688 [==============================] - 3s 10us/step - loss: 0.3065 - accuracy: 0.7803
# Epoch 51/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7793
# Epoch 52/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7800
# Epoch 53/100
# 290688/290688 [==============================] - 3s 11us/step - loss: 0.3065 - accuracy: 0.7788
# Epoch 54/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7791
# Epoch 55/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7789
# Epoch 56/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7793
# Epoch 57/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7784
# Epoch 58/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3065 - accuracy: 0.7793
# Epoch 59/100
# 290688/290688 [==============================] - 3s 10us/step - loss: 0.3065 - accuracy: 0.7794
# Epoch 60/100
# 290688/290688 [==============================] - 3s 9us/step - loss: 0.3064 - accuracy: 0.7788
# Epoch 61/100
# 290688/290688 [==============================] - 3s 12us/step - loss: 0.3065 - accuracy: 0.7786
# Epoch 62/100
# 290688/290688 [==============================] - 3s 12us/step - loss: 0.3064 - accuracy: 0.7796
# Epoch 63/100
# 290688/290688 [==============================] - 3s 12us/step - loss: 0.3064 - accuracy: 0.7796
# Epoch 64/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7794
# Epoch 65/100
# 290688/290688 [==============================] - 4s 15us/step - loss: 0.3064 - accuracy: 0.7793
# Epoch 66/100
# 290688/290688 [==============================] - 4s 14us/step - loss: 0.3065 - accuracy: 0.7790
# Epoch 67/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7790
# Epoch 68/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7795
# Epoch 69/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7792
# Epoch 70/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7801
# Epoch 71/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7800
# Epoch 72/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7785
# Epoch 73/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7793
# Epoch 74/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7790
# Epoch 75/100
# 290688/290688 [==============================] - 4s 14us/step - loss: 0.3064 - accuracy: 0.7793
# Epoch 76/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7802
# Epoch 77/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7792
# Epoch 78/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7783
# Epoch 79/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7801
# Epoch 80/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7786
# Epoch 81/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7788
# Epoch 82/100
# 290688/290688 [==============================] - 4s 14us/step - loss: 0.3064 - accuracy: 0.7802
# Epoch 83/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7793
# Epoch 84/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7778
# Epoch 85/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7780
# Epoch 86/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7792
# Epoch 87/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7791
# Epoch 88/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7795
# Epoch 89/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7790
# Epoch 90/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7794
# Epoch 91/100
# 290688/290688 [==============================] - 4s 14us/step - loss: 0.3064 - accuracy: 0.7784
# Epoch 92/100
# 290688/290688 [==============================] - 4s 15us/step - loss: 0.3064 - accuracy: 0.7786
# Epoch 93/100
# 290688/290688 [==============================] - 4s 14us/step - loss: 0.3064 - accuracy: 0.7783
# Epoch 94/100
# 290688/290688 [==============================] - 4s 14us/step - loss: 0.3064 - accuracy: 0.7788
# Epoch 95/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7785
# Epoch 96/100
# 290688/290688 [==============================] - 4s 12us/step - loss: 0.3064 - accuracy: 0.7780
# Epoch 97/100
# 290688/290688 [==============================] - 4s 14us/step - loss: 0.3064 - accuracy: 0.7784
# Epoch 98/100
# 290688/290688 [==============================] - 4s 15us/step - loss: 0.3064 - accuracy: 0.7801
# Epoch 99/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7789
# Epoch 100/100
# 290688/290688 [==============================] - 4s 13us/step - loss: 0.3064 - accuracy: 0.7790

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))

import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

index = ['Normal','Inner Race (0.021")', 'Outer Race (0.021")']  
columns = ['Normal','Inner Race (0.021")', 'Outer Race (0.021")']  
cm_df = pd.DataFrame(cm,columns,index)  


plt.figure(figsize=(10,4))
sn.set(font_scale=1.4) # for label size
sn.heatmap(cm_df, annot=True, fmt='g') # font size
plt.title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
classifier.evaluate(X_test, y_test)
# Out:
# 72672/72672 [==============================] - 1s 18us/step
# [0.3063910399263832, 0.792272686958313]

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test, y_pred, target_names=['Normal','Inner Race (0.021")', 'Outer Race (0.021")'])
print(cr)
# Out:
#                      precision    recall  f1-score   support
#
#              Normal       0.61      0.22      0.32     24508
# Inner Race (0.021")       1.00      1.00      1.00     24263
# Outer Race (0.021")       0.52      0.85      0.64     23901
#
#           micro avg       0.69      0.69      0.69     72672
#           macro avg       0.71      0.69      0.65     72672
#        weighted avg       0.71      0.69      0.65     72672
#         samples avg       0.69      0.69      0.69     72672
# C:\Users\leste\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
